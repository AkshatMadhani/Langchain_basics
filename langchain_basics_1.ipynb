# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatMadhani/Langchain_basics/blob/main/langchain_basics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ollama langchain_community groq langchain_groq

# %%
from google.colab import userdata
groq_api_key=userdata.get('groq_api_key')

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
llm = ChatGroq(model="llama-3.3-70b-versatile",groq_api_key=groq_api_key)
parser=StrOutputParser()
prompt=ChatPromptTemplate.from_template("tell me  joke about life in {engineering}")

# %%
chain = prompt | llm | parser

response = chain.invoke({"engineering": "assignemnts"})

print(response)
# Out:
# Why did the assignment go to therapy?
#
# Because it had a lot of "due" dates to work through and was feeling a little "graded" by life!
