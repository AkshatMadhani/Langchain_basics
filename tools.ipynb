# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshatMadhani/Langchain_basics/blob/main/tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-community serpapi
# !pip install google-search-results
# !pip install arxiv
# !pip install wikipedia

# %%
from langchain_community.utilities.serpapi import SerpAPIWrapper
from langchain.prompts import ChatPromptTemplate
from google.colab import userdata
serpapi_api_key=userdata.get('serp_api_key')
search = SerpAPIWrapper(serpapi_api_key=serpapi_api_key)
results = search.run("give me todays news top 10 news in india")
results
# Out:
# '["1. SC finds things \'amiss\' in the Kolkata rape-murder case · 2. Can\'t leave manufacturing to China, Rahul tells Indians in US · 3. How construction boom caused ...", "Top News ; Don\'t Miss · Katrina Kaif reviews Chhaava, calls Vicky Kaushal a \'chameleon\' for his act · Bollywood. Updated -39 min ago ; Cricket · Babar Azam beats ...", "F-35 jets, energy deals, and trade talks: PM Modi, President Trump meet to strengthen India-US ties · \'Viksit Bharat 2047 means Make India Great Again\': Key ...", \'Assembly Elections 2025 · CPI(M) Polit Bureau member Brinda Karat. · Niti Aayog logo. · J&K police seize 668 books promoting ideology of banned group in Srinagar.\', "TOP Headlines · Sanam Teri Kasam box office Day 7: Harshvardhan\'s film earns Rs 30 crore in a week · Seven-year-old girl crushed to death after gate collapses on ...", "India News · Trump-Modi Summit: $25 Deal, F-35 Jets, 26/11 · Rajya Sabha Waqf Fight: \'Won\'t Accept Your Report\' | Kharge Vs · AIMIM Helped BJP? · 
# ...

# %%
from langchain_community.utilities.arxiv import ArxivAPIWrapper
arxiv = ArxivAPIWrapper()
arxiv_results = arxiv.run("nlp sentiment analysis")
arxiv_results
# Out:
# 'Published: 2023-07-04\nTitle: Sentiment analysis and opinion mining on E-commerce site\nAuthors: Fatema Tuz Zohra Anny, Oahidul Islam\nSummary: Sentiment analysis or opinion mining help to illustrate the phrase NLP\n(Natural Language Processing). Sentiment analysis has been the most significant\ntopic in recent years. The goal of this study is to solve the sentiment\npolarity classification challenges in sentiment analysis. A broad technique for\ncategorizing sentiment opposition is presented, along with comprehensive\nprocess explanations. With the results of the analysis, both sentence-level\nclassification and review-level categorization are conducted. Finally, we\ndiscuss our plans for future sentiment analysis research.\n\nPublished: 2017-07-04\nTitle: Sentiment Identification in Code-Mixed Social Media Text\nAuthors: Souvick Ghosh, Satanu Ghosh, Dipankar Das\nSummary: Sentiment analysis is the Natural Language Processing (NLP) task dealing with\nthe detection and classificatio
# ...

# %%
from langchain_community.utilities import WikipediaAPIWrapper
wiki = WikipediaAPIWrapper()
wiki_results = wiki.run("elon musk career")
print(wiki_results)
# Out:
# Page: Business career of Elon Musk
# Summary: Elon Musk is a businessman known predominantly for his leading roles in the automotive company Tesla, Inc. and the space company SpaceX. Musk is also known for his ownership of technology company X Corp. and his role in the founding of the Boring Company, xAI, Neuralink, and OpenAI.
# ...
